# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("features.csv")
df.dropna()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 92        1  11-11-2011        59.11       3.297   10382.90    6115.67
# 93        1  18-11-2011        62.25       3.308    6074.12     254.39
# 94        1  25-11-2011        60.14       3.236     410.31      98.00
# 95        1  02-12-2011        48.91       3.172    5629.51      68.00
# 96        1  09-12-2011        43.93       3.158    4640.65      19.00
# ...     ...         ...          ...         ...        ...        ...
# 8168     45  01-03-2013        39.72       3.890    6614.32     147.82
# 8169     45  08-03-2013        36.13       3.860   16382.54      88.67
# 8173     45  05-04-2013        43.94       3.763   16427.83    5341.41
# 8174     45  12-04-2013        57.39       3.724    8760.15    1713.11
# 8175     45  19-04-2013        56.27       3.676    1399.81      39.89
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Visualization 1: Line plot showing the trend of Temperature over time
plt.figure(figsize=(10, 5))
sns.lineplot(x='Date', y='Temperature', data=df, marker='o')
plt.title('Temperature Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\gokulan\AppData\Local\Temp\ipykernel_22008\941974884.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\gokulan\AppData\Local\Temp\ipykernel_22008\941974884.py:59: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")

# %%
# Visualization 2: Scatter plot showing the relationship between CPI and Unemployment
plt.figure(figsize=(8, 6))
sns.scatterplot(x='CPI', y='Unemployment', data=df)
plt.title('CPI vs Unemployment')
plt.xlabel('CPI')
plt.ylabel('Unemployment')
plt.grid(True)
plt.show()

# %%
# Visualization 3: Box plot to visualize the distribution of Fuel Price
plt.figure(figsize=(8, 6))
sns.boxplot(x='Fuel_Price', data=df)
plt.title('Distribution of Fuel Price')
plt.xlabel('Fuel Price')
plt.grid(True)
plt.show()

# %%
# Visualization 4: Histogram of Markdown1
plt.figure(figsize=(8, 6))
sns.histplot(df['MarkDown1'], kde=True)
plt.title('Histogram of Markdown1')
plt.xlabel('Markdown1')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Visualization 5: Bar plot showing average Markdown2 for each store
average_markdown2 = df.groupby('Store')['MarkDown2'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Store', y='MarkDown2', data=average_markdown2)
plt.title('Average Markdown2 for Each Store')
plt.xlabel('Store')
plt.ylabel('Average Markdown2')
plt.grid(True)
plt.show()

# %%
# Visualization 6: Pie chart to represent the proportion of holidays
holiday_proportion = df['IsHoliday'].value_counts(normalize=True)
plt.figure(figsize=(6, 6))
plt.pie(holiday_proportion, labels=holiday_proportion.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Holidays')
plt.axis('equal')
plt.show()

# %%
# Visualization 7: Heatmap to visualize the correlation matrix of the numerical features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\gokulan\AppData\Local\Temp\ipykernel_22008\1089605789.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
